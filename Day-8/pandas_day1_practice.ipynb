# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('student.csv')

# %%
#Print first 5 rows
df.head()
# Out:
#    id           name  math  english  science
# 0   1  Alice Johnson    85       92       78
# 1   2      Bob Smith    70       65       80
# 2   3  Charlie Brown    95       88       92
# 3   4   David Wilson    50       45       55
# 4   5   Eva Martinez    88       91       83

# %%
#Print last 5 rows
df.tail()
# Out:
#      id               name  math  english  science
# 95   96  Sebastian Bennett    79       81       80
# 96   97      Tessa Simmons    84       86       85
# 97   98     Ulysses Foster    92       94       93
# 98   99     Valeria Bryant    74       76       75
# 99  100        Wyatt Hayes    81       83       82

# %%
#Print column names
df.columns
# Out:
# Index(['id', 'name', 'math', 'english', 'science'], dtype='str')

# %%
print(df.columns.tolist())
# Out:
# ['id', 'name', 'math', 'english', 'science']

# %%
# Print dataset shape
df.shape
# Out:
# (100, 5)

# %%
# Filter students with math marks ≥ 80
math_marks = df[df['math'] >= 00]
math_marks
# Out:
#      id               name  math  english  science
# 0     1      Alice Johnson    85       92       78
# 1     2          Bob Smith    70       65       80
# 2     3      Charlie Brown    95       88       92
# 3     4       David Wilson    50       45       55
# 4     5       Eva Martinez    88       91       83
# ..  ...                ...   ...      ...      ...
# 95   96  Sebastian Bennett    79       81       80
# 96   97      Tessa Simmons    84       86       85
# 97   98     Ulysses Foster    92       94       93
# 98   99     Valeria Bryant    74       76       75
# 99  100        Wyatt Hayes    81       83       82
#
# [100 rows x 5 columns]

# %%
# Calculate average marks per subject
average_marks = df[['math', 'english', 'science']].agg('mean')
average_marks
# Out:
# math       81.20
# english    83.31
# science    82.25
# dtype: float64

# %%
# Sort students by science marks (descending)
sorted_science = df[['name', 'science']].sort_values(by='science', ascending=False)
sorted_science
# Out:
#                 name  science
# 17       Ryan Nguyen       95
# 64       Nora Bryant       94
# 24        Yara Perez       94
# 84    Harper Griffin       94
# 44  Savannah Bennett       94
# ..               ...      ...
# 45     Tyler Simmons       67
# 85          Ian Diaz       67
# 65        Owen Hayes       67
# 25      Zane Roberts       66
# 3       David Wilson       55
#
# [100 rows x 2 columns]

# %%
df.describe()
# Out:
#                id        math     english   science
# count  100.000000  100.000000  100.000000  100.0000
# mean    50.500000   81.200000   83.310000   82.2500
# std     29.011492    8.764022    8.919047    8.1926
# min      1.000000   50.000000   45.000000   55.0000
# 25%     25.750000   75.000000   78.750000   77.7500
# 50%     50.500000   82.500000   84.500000   83.0000
# 75%     75.250000   88.000000   90.000000   88.2500
# max    100.000000   95.000000   95.000000   95.0000

# %%
# Filter students who scored less than 60 in any subject
less_than_60 = df[(df['math'] < 60) | (df['english'] < 60) | (df['science'] < 60)]
less_than_60
# Out:
#    id          name  math  english  science
# 3   4  David Wilson    50       45       55

# %%
# Count how many students scored above 80 in English
high_english_marks = df[df['english'] > 80][['id', 'name', 'english']]
high_english_marks
# Out:
#      id               name  english
# 0     1      Alice Johnson       92
# 2     3      Charlie Brown       88
# 4     5       Eva Martinez       91
# 5     6       Frank Thomas       84
# 7     8       Henry Walker       87
# ..  ...                ...      ...
# 94   95        Ruby Flores       90
# 95   96  Sebastian Bennett       81
# 96   97      Tessa Simmons       86
# 97   98     Ulysses Foster       94
# 99  100        Wyatt Hayes       83
#
# [65 rows x 3 columns]

# %%
#Check if there are any missing values in the dataset
df.isnull().sum()
# Out:
# id         0
# name       0
# math       0
# english    0
# science    0
# dtype: int64
