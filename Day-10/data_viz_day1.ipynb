# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Create dataset
data = {
    'Student': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Math': [85, 90, 78, 92, 88],
    'Science': [80, 95, 75, 89, 92],
    'English': [78, 85, 82, 88, 90]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#    Student  Math  Science  English
# 0    Alice    85       80       78
# 1      Bob    90       95       85
# 2  Charlie    78       75       82
# 3    David    92       89       88
# 4      Eva    88       92       90
