# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Create dataset
data = {
    'Student': [
        'Alice', 'Bob', 'Charlie', 'David', 'Eva',
        'Frank', 'Grace', 'Hannah', 'Ian', 'Julia',
        'Kevin', 'Laura', 'Mike', 'Nina', 'Oscar',
        'Paula', 'Quinn', 'Rachel', 'Steve', 'Tina'
    ],
    'Math': [
        85, 90, 78, 92, 88,
        74, 81, 89, 76, 94,
        87, 82, 79, 91, 84,
        86, 88, 90, 77, 93
    ],
    'Science': [
        80, 95, 75, 89, 92,
        78, 84, 91, 73, 96,
        85, 83, 77, 90, 88,
        87, 89, 92, 76, 94
    ],
    'English': [
        78, 85, 82, 88, 90,
        75, 80, 87, 79, 91,
        84, 81, 76, 89, 85,
        83, 86, 88, 78, 92
    ]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#     Student  Math  Science  English
# 0     Alice    85       80       78
# 1       Bob    90       95       85
# 2   Charlie    78       75       82
# 3     David    92       89       88
# 4       Eva    88       92       90
# 5     Frank    74       78       75
# 6     Grace    81       84       80
# 7    Hannah    89       91       87
# 8       Ian    76       73       79
# 9     Julia    94       96       91
# 10    Kevin    87       85       84
# 11    Laura    82       83       81
# 12     Mike    79       77       76
# 13     Nina    91       90       89
# 14    Oscar    84       88       85
# 15    Paula    86       87       83
# 16    Quinn    88       89       86
# 17   Rachel    90       92       88
# 18    Steve    77       76       78
# 19     Tina    93       94       92

# %%
# ---------- Line Chart (Math)----------
plt.figure(figsize=(14,7), dpi = 120)
plt.plot(df['Student'], df['Math'], marker='o', label='Math', color = 'blue')
plt.title('Students Marks (Math)', fontsize=16)

plt.xlabel('Students')
plt.ylabel('Marks')

plt.xticks(rotation=45)
plt.legend(loc='upper left', fontsize=12) 
plt.grid(True)
plt.show()

# %%
# ---------- Line Chart (Science)----------
plt.figure(figsize=(14,7), dpi = 120)
plt.plot(df['Student'], df['Science'], marker='s', label='Science', color = 'green')
plt.title('Students Marks (Science)', fontsize=16)

plt.xlabel('Students')
plt.ylabel('Marks')

plt.xticks(rotation=45)
plt.legend(loc='upper left', fontsize=12)  
plt.grid(True)

plt.show()

# %%
# ---------- Line Chart (English)----------
plt.figure(figsize=(14,7), dpi = 120)
plt.plot(df['Student'], df['English'], marker='^', label='English', color = 'purple')
plt.title('Students Marks (English)', fontsize=16)

plt.xlabel('Students')
plt.ylabel('Marks')

plt.xticks(rotation=45)
plt.legend(loc='upper left', fontsize=12)  
plt.grid(True)

plt.show()

# %%
# ---------- Line Chart (All subjects)----------
plt.figure(figsize=(16,8), dpi = 120)

plt.plot(df['Student'], df['Math'], marker='o', label='Math')
plt.plot(df['Student'], df['Science'], marker='s', label='Science')
plt.plot(df['Student'], df['English'], marker='^', label='English')
plt.title('Students Marks Comparison Line Chart', fontsize=16)

plt.xlabel('Students')
plt.ylabel('Marks')

plt.legend(loc='upper left', fontsize=12)
plt.grid(True)

plt.savefig("line.png")

plt.show()

# %%
# ---------- Bar Chart (Math)----------
plt.figure(figsize=(16,8), dpi = 120)
x = range(len(df['Student']))

plt.bar(x, df['Math'], label='Math', color = 'blue')

plt.title('Math Marks Bar Chart', fontsize=16)
plt.xlabel('Students')
plt.ylabel('Marks')
plt.xticks(x, df['Student'], rotation=45)
plt.legend(loc='upper left', fontsize=12)

plt.tight_layout()
plt.show()

# %%
# ---------- Bar Chart (Science)----------
plt.figure(figsize=(16,8), dpi = 120)
x = range(len(df['Science']))

plt.bar(x, df['Science'], label='Science', color = 'green')

plt.title('Science Marks Bar Chart', fontsize=16)
plt.xlabel('Students')
plt.ylabel('Marks')
plt.xticks(x, df['Student'], rotation=45)
plt.legend(loc='upper left', fontsize=12)

plt.tight_layout()
plt.show()

# %%
# ---------- Bar Chart (English)----------
plt.figure(figsize=(16,8), dpi = 120)
x = range(len(df['English']))

plt.bar(x, df['English'], label='English', color = 'purple')

plt.title('English Marks Bar Chart', fontsize=16)
plt.xlabel('Students')
plt.ylabel('Marks')
plt.xticks(x, df['Student'], rotation=45)
plt.legend(loc='upper left', fontsize=12)

plt.tight_layout()
plt.show()

# %%
# ---------- Bar Chart (All subjects)----------
plt.figure(figsize=(16,8), dpi = 120)

bar_width = 0.25
x = range(len(df['Student']))

plt.bar(x, df['Math'], width = bar_width, label='Math')
plt.bar([i + bar_width for i in x], df['Science'], width = bar_width, label='Science')
plt.bar([i + bar_width*2 for i in x], df['English'], width = bar_width, label='English')

plt.title('Students Marks Comparison Bar Chart', fontsize=16)
plt.xlabel('Students')
plt.ylabel('Marks')
plt.xticks([i + bar_width for i in x], df['Student'], rotation=45)
plt.legend(loc='upper left', fontsize=12)

plt.tight_layout()
plt.savefig("Bar_plot.png")

plt.show()

# %%
# ---------- Histogram (Math marks)----------
plt.figure(figsize=(16,8), dpi=120)

plt.hist(df['Math'], bins=5, alpha=0.7, label='Math', color = 'blue')

plt.title('Math Marks Distribution Histogram', fontsize=16)
plt.xlabel('Marks')
plt.ylabel('Frequency')
plt.legend(loc='upper left', fontsize=12)

plt.tight_layout()
plt.show()

# %%
# ---------- Histogram (Science marks)----------
plt.figure(figsize=(16,8), dpi=120)

plt.hist(df['Science'], bins=5, alpha=0.7, label='Science', color = 'green')

plt.title('Science Marks Distribution Histogram', fontsize=16)
plt.xlabel('Marks')
plt.ylabel('Frequency')
plt.legend(loc='upper left', fontsize=12)

plt.tight_layout()
plt.show()

# %%
# ---------- Histogram (English marks)----------
plt.figure(figsize=(16,8), dpi=120)

plt.hist(df['English'], bins=5, alpha=0.7, label='English', color = 'purple')

plt.title('English Marks Distribution Histogram', fontsize=16)
plt.xlabel('Marks')
plt.ylabel('Frequency')
plt.legend(loc='upper left', fontsize=12)

plt.tight_layout()
plt.show()

# %%
# ---------- Histogram (All subjects)----------
plt.figure(figsize=(16,8), dpi=120)

plt.hist(df['Math'], bins=5, alpha=0.5, label='Math')
plt.hist(df['Science'], bins=5, alpha=0.5, label='Science')
plt.hist(df['English'], bins=5, alpha=0.5, label='English')

plt.title('Marks Distribution Comparison Histogram', fontsize=16)
plt.xlabel('Marks')
plt.ylabel('Frequency')
plt.legend(loc='upper left', fontsize=12)

plt.tight_layout()
plt.savefig("histogram_plot.png")

plt.show()

# %%
# ---------- Scatter Plot (Math vs Science)----------
plt.figure(figsize=(16,8), dpi=120)

plt.scatter(df['Math'], df['Science'], label='Math vs Science', s=100, color ='blue')

plt.title('Math vs Science Scatter Plot', fontsize=16)
plt.xlabel('Math Marks')
plt.ylabel('Science Marks')
plt.legend(loc='upper left', fontsize=12)

plt.tight_layout()
plt.show()

# %%
# ---------- Scatter Plot (Math vs English)----------
plt.figure(figsize=(16,8), dpi=120)

plt.scatter(df['Math'], df['English'], label='Math vs English', s=100, color = 'green')

plt.title('Math vs English Scatter Plot', fontsize=16)
plt.xlabel('Math Marks')
plt.ylabel('English Marks')
plt.legend(loc='upper left', fontsize=12)

plt.tight_layout()
plt.show()

# %%
# ---------- Scatter Plot (Science vs English)----------
plt.figure(figsize=(16,8), dpi=120)

plt.scatter(df['Science'], df['English'], label='Science vs English', s=100, color = 'purple')

plt.title('Science vs English Scatter Plot', fontsize=16)
plt.xlabel('Science Marks')
plt.ylabel('English Marks')
plt.legend(loc='upper left', fontsize=12)

plt.tight_layout()
plt.show()

# %%
# ---------- Scatter Plot ----------
plt.figure(figsize=(16,8), dpi=120)

plt.scatter(df['Math'], df['Science'], label='Math vs Science', s=100)
plt.scatter(df['Math'], df['English'], label='Math vs English', s=100)
plt.scatter(df['Science'], df['English'], label='Science vs English', s=100)

plt.title('Combined Scatter Plot of Students Marks', fontsize=16)
plt.xlabel('Subject Marks')
plt.ylabel('Other Subject Marks')
plt.legend(loc='upper left', fontsize=12)

plt.tight_layout()
plt.savefig("scatter_plot.png")

plt.show()

# %%
# ---------- Pie Chart (Math marks)----------
plt.figure(figsize=(16,8), dpi=120)
plt.pie(
    df['Math'],
    labels=df['Student'],
    autopct='%1.1f%%',
    startangle=90
)
plt.title('Math Marks Distribution by Student')
plt.tight_layout()
plt.show()

# %%
# ---------- Pie Chart (Science marks)----------
plt.figure(figsize=(16,8), dpi=120)

plt.pie(
    df['Science'],
    labels=df['Student'],
    autopct='%1.1f%%',
    startangle=90
)
plt.title('Science Marks Distribution by Student')

plt.tight_layout()
plt.show()

# %%
# ---------- Pie Chart (English marks)----------
plt.figure(figsize=(16,8), dpi=120)

plt.pie(
    df['English'],
    labels=df['Student'],
    autopct='%1.1f%%',
    startangle=90
)
plt.title('English Marks Distribution by Student')

plt.tight_layout()
plt.show()

# %%
# ---------- Pie Chart ---------- #
# Average marks per subject #
avg_marks = df[['Math', 'Science', 'English']].mean() 

plt.figure(figsize=(16,8), dpi=120) 
plt.pie(avg_marks, labels=avg_marks.index, autopct='%1.1f%%', startangle=90) 

plt.title('Average Marks Pie Chart') 
plt.savefig("pie_chart.png")

plt.show()
